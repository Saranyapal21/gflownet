# %%
import numpy as np
import pandas as pd
import gymnasium as gym

import torch
import sentencepiece as spm

# %%
with open('D:/GFlowNet/Datasets/wat-2021/dev.en', encoding='UTF-8') as f:
    text = f.read()

# %%
print(len(text))
print(len(text.split()))        #   Approx 16k words
# Out:
# 101716
# 16322

# %%
help(spm.SentencePieceTrainer.train)
# Out:
# Help on function Train in module sentencepiece:
#
# Train(arg=None, logstream=None, **kwargs)

# %%
train_size = 0.2
n = int(len(text)*train_size)
train_text = text[:n]
test_text = text[n:]

# %%
with open('train.txt', 'w', encoding='utf-8') as f:
    f.write(train_text)

with open('test.txt', 'w', encoding='utf-8') as f:
    f.write(test_text)

# %%
import os
os.getcwd()
# Out:
# 'd:\\GFlowNet\\My_Experiments'

# %%
spm.SentencePieceTrainer.train(
    input = 'train.txt',
    model_prefix = 'tokenizer',
    vocab_size = 1000,
    model_type = 'char'
    # charecter_coverage = 1.0
)

# %%
sp = spm.SentencePieceProcessor()
sp.load('tokenizer.model')
# Out:
# True

# %%
k = 100
print(test_text[:k])

pieces = sp.encode(test_text[:k], out_type=str)
print("Pieces:", pieces)
# Out:
# tasks which seem extremely difficult.
# He said organizations such as the WHO have appreciated the pro
# Pieces: ['▁', 't', 'a', 's', 'k', 's', '▁', 'w', 'h', 'i', 'c', 'h', '▁', 's', 'e', 'e', 'm', '▁', 'e', 'x', 't', 'r', 'e', 'm', 'e', 'l', 'y', '▁', 'd', 'i', 'f', 'f', 'i', 'c', 'u', 'l', 't', '.', '▁', 'H', 'e', '▁', 's', 'a', 'i', 'd', '▁', 'o', 'r', 'g', 'a', 'n', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', '▁', 's', 'u', 'c', 'h', '▁', 'a', 's', '▁', 't', 'h', 'e', '▁', 'W', 'H', 'O', '▁', 'h', 'a', 'v', 'e', '▁', 'a', 'p', 'p', 'r', 'e', 'c', 'i', 'a', 't', 'e', 'd', '▁', 't', 'h', 'e', '▁', 'p', 'r', 'o']

# %%
from typing import Literal

class SentencePiece_Tokenizer:
    def __init__(self):
        super().__init__()
        self.sp = spm.SentencePieceProcessor()


    def token_to_ids(self, tokens):
        return [self.sp.piece_to_id(token) for token in tokens]


    def ids_to_tokens(self, ids):
        return [self.sp.id_to_piece(id_) for id_ in ids]


    def train_tokenizer(self, file_path: str, vocab_size: int, token_type: Literal['bpe', 'unigram', 'char', 'word'] = 'bpe', model_name: str='tokenizer', **kwargs):

        spm.SentencePieceTrainer.train(
            input = file_path,
            model_prefix = str(token_type + '_' + model_name),
            vocab_size = vocab_size,
            model_type = token_type
        )            

    
    def encode(self, model_path, text: str, out_type: str | int):
        self.sp.load(model_path)

        tokens = self.sp.encode(text, out_type=out_type)
        return tokens
    

    def join_token(self, token):
        if isinstance(token[0], int):
            return self.sp.decode(token)
        return self.sp.decode_pieces(token)


    def disjoin_token(self):
        pass

# %% [markdown]
# Refer to this [Colab_Link](https://colab.research.google.com/github/google/sentencepiece/blob/master/python/sentencepiece_python_module_example.ipynb) for detailed examples of SentencePiece

# %%
#   A Basic GPT code :)

class TokenizeEnv(gym.Env):
    def __init__(self, text):
        super().__init__()
        self.text = text.strip()
        self.reset()

    def reset(self):
        self.state = list(self.text)  # start with character-level tokens
        return self.state

    def step(self, action):
        i, j = action
        if j != i + 1 or i < 0 or j >= len(self.state):
            raise ValueError("Invalid merge action")

        merged_token = self.state[i] + self.state[j]
        self.state = self.state[:i] + [merged_token] + self.state[j+1:]

        done = self.is_terminal()
        reward = self.compute_reward() if done else 0

        return self.state, reward, done, {}

    def is_terminal(self):
        return len(self.state) <= 3  # or some custom stopping condition

    def compute_reward(self):
        return -len(self.state)  # toy reward: fewer tokens = better

# %%
env = TokenizeEnv(test_text)
print(env.state)
# Out:
# ['t', 'a', 's', 'k', 's', ' ', 'w', 'h', 'i', 'c', 'h', ' ', 's', 'e', 'e', 'm', ' ', 'e', 'x', 't', 'r', 'e', 'm', 'e', 'l', 'y', ' ', 'd', 'i', 'f', 'f', 'i', 'c', 'u', 'l', 't', '.', '\n', 'H', 'e', ' ', 's', 'a', 'i', 'd', ' ', 'o', 'r', 'g', 'a', 'n', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', ' ', 's', 'u', 'c', 'h', ' ', 'a', 's', ' ', 't', 'h', 'e', ' ', 'W', 'H', 'O', ' ', 'h', 'a', 'v', 'e', ' ', 'a', 'p', 'p', 'r', 'e', 'c', 'i', 'a', 't', 'e', 'd', ' ', 't', 'h', 'e', ' ', 'p', 'r', 'o', 'g', 'r', 'e', 's', 's', ' ', 'm', 'a', 'd', 'e', ' ', 'i', 'n', ' ', 't', 'h', 'e', ' ', 'S', 'w', 'a', 'c', 'h', 'h', ' ', 'B', 'h', 'a', 'r', 'a', 't', ' ', 'M', 'i', 's', 's', 'i', 'o', 'n', '.', '\n', 'S', 'h', 'r', 'i', ' ', 'N', 'a', 'r', 'e', 'n', 'd', 'r', 'a', ' ', 'M', 'o', 'd', 'i', ' ', 'a', 'n', 'n', 'o', 'u', 'n', 'c', 'e', 'd', ' ', 't', 'h', 'e', ' ', 'l', 'a', 'u', 'n', 'c', 'h', ' ', 'o', 'f', ' ', 't', 'h', 'e', ' ', 'P', 'r', 'a', 'd', 'h', 'a', 'n', ' ', 'M', 'a', 'n', 't', 'r', 'i', ' ', 'J', 'a', 'n', ' ', 'A', 'r', 'o', 'g', 'y', 'a', ' ', 'A', 'b', 'h', 'i', 'y', 'a', 'a', 'n', ' ', 'o', 'n', ' ', '2', '5', 't', 'h', ' ', 'S', 'e', 'p', 't', 'e', 'm', 'b', 'e', 'r', ' ', 't', 'h', 'i', 's', ' ', 'y', 'e', 'a', 'r', ' ', '–', ' ', 't', 'h', 'e', ' ', 'a', 'n', 'n', 'i', 'v', 'e', 'r', 's', 'a', 'r', 'y', ' ', 'o', 'f', ' ', 'P', 'a', 'n', 'd', 'i', 't', ' ', 'D', 'e', 'e', 'n', 'd', 'a', 'y', 'a', 'l', ' ', 'U', 'p', 'a', 'd', 'h', 'y', 'a', 'y', '.', '\n', 'T', 'h', 'e', ' ', 'P', 'r', 'i', 'm', 'e', ' ', 'M', 'i', 'n', 'i', 's', 't', 'e', 'r', ' ', 'a', 'n', 'n', 'o', 'u', 'n', 'c', 'e', 'd', ' ', 't', 'h', 'a', 't', ' ', 'w', 'o', 'm', 'e', 'n', ' ', 'o', 'f', 'f', 'i', 'c', 'e', 'r', 's', ' ', 'o', 'f', ' ', 'S', 'h', 'o', 'r', 't', ' ', 'S', 'e', 'r', 'v', 'i', 'c', 'e', ' ', 'C', 'o', 'm', 'm', 'i', 's', 's', 'i', 'o', 'n', ' ', 'i', 'n', ' ', 't', 'h', 'e', ' ', 'I', 'n', 'd', 'i', 'a', 'n', ' ', 'A', 'r', 'm', 'e', 'd', ' ', 'F', 'o', 'r', 'c', 'e', 's', ' ', 'w', 'o', 'u', 'l', 'd', ' ', 'n', 'o', 'w', ' ', 'b', 'e', ' ', 'e', 'l', 'i', 'g', 'i', 'b', 'l', 'e', ' ', 'f', 'o', 'r', ' ', 'p', 'e', 'r', 'm', 'a', 'n', 'e', 'n', 't', ' ', 'c', 'o', 'm', 'm', 'i', 's', 's', 'i', 'o', 'n', ' ', 't', 'h', 'r', 'o', 'u', 'g', 'h', ' ', 'a', ' ', 't', 'r', 'a', 'n', 's', 'p', 'a', 'r', 'e', 'n', 't', ' ', 's', 'e', 'l', 'e', 'c', 't', 'i', 'o', 'n', ' ', 'p', 'r', 'o', 'c', 'e', 's', 's', '.', '\n', 'H', 'e', ' ', 'e', 'm', 'p', 'h', 'a', 's', 'i', 'z', 'e', 'd', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'v', 'i', 's', 'i', 'o', 'n', ' ', 'o', 'f', ' ', 'H', 'o', 'u', 's', 'i', 'n', 'g', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'P', 'o', 'w', 'e', 'r', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'C', 'l', 'e', 'a', 'n', ' ', 'C', 'o', 'o', 'k', 'i', 'n', 'g', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'W', 'a', 't', 'e', 'r', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'S', 'a', 'n', 'i', 't', 'a', 't', 'i', 'o', 'n', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'S', 'k', 'i', 'l', 'l', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'H', 'e', 'a', 'l', 't', 'h', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'I', 'n', 's', 'u', 'r', 'a', 'n', 'c', 'e', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', ',', ' ', 'a', 'n', 'd', ' ', 'C', 'o', 'n', 'n', 'e', 'c', 't', 'i', 'v', 'i', 't', 'y', ' ', 'f', 'o', 'r', ' ', 'A', 'l', 'l', '.', '\n', '“', 'R', 'e', 'm', 'e', 'm', 'b', 'e', 'r', 'i', 'n', 'g', ' ', 'o', 'u', 'r', ' ', 'f', 'i', 'r', 's', 't', ' ', 'P', 'r', 'i', 'm', 'e', ' ', 'M', 'i', 'n', 'i', 's', 't', 'e', 'r', ',', ' ', 'P', 'a', 'n', 'd', 'i', 't', ' ', 'J', 'a', 'w', 'a', 'h', 'a', 'r', 'l', 'a', 'l', ' ', 'N', 'e', 'h', 'r', 'u', ' ', 'o', 'n', ' ', 'h', 'i', 's', ' ', 'b', 'i', 'r', 't', 'h', ' ', 'a', 'n', 'n', 'i', 'v', 'e', 'r', 's', 'a', 'r', 'y', '.', '\n', 'I', 't', ' ', 'w', 'i', 'l', 'l', ' ', 'h', 'e', 'l', 'p', ' ', 's', 'p', 'r', 'e', 'a', 'd', ' ', 'a', 'w' ...

# %%
env.step((5,6))
# Out:
# (['t',
#   'a',
#   's',
#   'k',
#   's',
#   ' w',
#   'h',
#   'i',
#   'c',
#   'h',
#   ' ',
#   's',
#   'e',
#   'e',
#   'm',
#   ' ',
#   'e',
#   'x',
#   't',
#   'r',
#   'e',
#   'm',
#   'e',
#   'l',
#   'y',
#   ' ',
#   'd',
#   'i',
#   'f',
#   'f',
#   'i',
#   'c',
#   'u',
#   'l',
#   't',
#   '.',
#   '\n',
#   'H',
#   'e',
#   ' ',
#   's',
#   'a',
#   'i',
#   'd',
#   ' ',
#   'o',
#   'r',
#   'g',
#   'a',
#   'n',
#   'i',
#   'z',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   's',
#   ' ',
#   's',
#   'u',
#   'c',
#   'h',
#   ' ',
#   'a',
#   's',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'W',
#   'H',
#   'O',
#   ' ',
#   'h',
#   'a',
#   'v',
#   'e',
#   ' ',
#   'a',
#   'p',
#   'p',
#   'r',
#   'e',
#   'c',
#   'i',
#   'a',
#   't',
#   'e',
#   'd',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'g',
#   'r',
#   'e',
#   's',
#   's',
#   ' ',
#   'm',
#   'a',
#   'd',
#   'e',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'S',
#   'w',
#   'a',
#   'c',
#   'h',
#   'h',
#   ' ',
#   'B',
#   'h',
#   'a',
#   'r',
#   'a',
#   't',
#   ' ',
#   'M',
#   'i',
#   's',
#   's',
#   'i',
#   'o',
#   'n',
#   '.',
#   '\n',
#   'S',
#   'h',
#   'r',
#   'i',
#   ' ',
#   'N',
#   'a',
#   'r',
#   'e',
#   'n',
#   'd',
#   'r',
#   'a',
#   ' ',
#   'M',
#   'o',
#   'd',
#   'i',
#   ' ',
#   'a',
#   'n',
#   'n',
#   'o',
#   'u',
#   'n',
#   'c',
#   'e',
#   'd',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'l',
#   'a',
#   'u',
#   'n',
#   'c',
#   'h',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'P',
#   'r',
#   'a',
#   'd',
#   'h',
#   'a',
#   'n',
#   ' ',
#   'M',
#   'a',
#   'n',
#   't',
#   'r',
#   'i',
#   ' ',
#   'J',
#   'a',
#   'n',
#   ' ',
#   'A',
#   'r',
#   'o',
#   'g',
#   'y',
#   'a',
#   ' ',
#   'A',
#   'b',
#   'h',
#   'i',
#   'y',
#   'a',
#   'a',
#   'n',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   '2',
#   '5',
#   't',
#   'h',
#   ' ',
#   'S',
#   'e',
#   'p',
#   't',
#   'e',
#   'm',
#   'b',
#   'e',
#   'r',
#   ' ',
#   't',
#   'h',
#   'i',
#   's',
#   ' ',
#   'y',
#   'e',
#   'a',
#   'r',
#   ' ',
#   '–',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'a',
#   'n',
#   'n',
#   'i',
#   'v',
#   'e',
#   'r',
#   's',
#   'a',
#   'r',
#   'y',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'P',
#   'a',
#   'n',
#   'd',
#   'i',
#   't',
#   ' ',
#   'D',
#   'e',
#   'e',
#   'n',
#   'd',
#   'a',
#   'y',
#   'a',
#   'l',
#   ' ',
#   'U',
#   'p',
#   'a',
#   'd',
#   'h',
#   'y',
#   'a',
#   'y',
#   '.',
#   '\n',
#   'T',
#   'h',
#   'e',
#   ' ',
#   'P',
#   'r',
#   'i',
#   'm',
#   'e',
#   ' ',
#   'M',
#   'i',
#   'n',
#   'i',
#   's',
#   't',
#   'e',
#   'r',
#   ' ',
#   'a',
#   'n',
#   'n',
#   'o',
#   'u',
#   'n',
#   'c',
#   'e',
#   'd',
#   ' ',
#   't',
#   'h',
#   'a',
#   't',
#   ' ',
#   'w',
#   'o',
#   'm',
#   'e',
#   'n',
#   ' ',
#   'o',
#   'f',
#   'f',
#   'i',
#   'c',
#   'e',
#   'r',
#   's',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'S',
#   'h',
#   'o',
#   'r',
#   't',
#   ' ',
#   'S',
#   'e',
#   'r',
#   'v',
#   'i',
#   'c',
#   'e',
#   ' ',
#   'C',
#   'o',
#   'm',
#   'm',
#   'i',
#   's',
#   's',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'I',
#   'n',
#   'd',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'A',
#   'r',
#   'm',
#   'e',
#   'd',
#   ' ',
#   'F',
#   'o',
#   'r',
#   'c',
#   'e',
#   's',
#   ' ',
#   'w',
#   'o',
#   'u',
#   'l',
#   'd',
#   ' ',
#   'n',
#   'o',
#   'w',
#   ' ',
#   'b',
#   'e',
#   ' ',
#   'e',
#   'l',
#   'i',
#   'g',
#   'i',
#   'b',
#   'l',
#   'e',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'p',
#   'e',
#   'r',
#   'm',
#   'a',
#   'n',
#   'e',
#   'n',
#   't',
#   ' ',
#   'c',
#   'o',
#   'm',
#   'm',
#   'i',
#   's',
#   's',
#   'i',
#   'o',
#   'n',
#   ' ',
#   't',
#   'h',
#   'r',
#   'o',
#   'u',
#   'g',
#   'h',
#   ' ',
#   'a',
#   ' ',
#   't',
#   'r',
#   'a',
#   'n',
#   's',
#   'p',
#   'a',
#   'r',
#   'e',
#   'n',
#   't',
#   ' ',
#   's',
#   'e',
#   'l',
#   'e',
#   'c',
#   't',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'c',
#   'e',
#   's',
#   's',
#   '.',
#   '\n',
#   'H',
#   'e',
#   ' ',
#   'e',
#   'm',
#   'p',
#   'h',
#   'a',
#   's',
#   'i',
#   'z',
#   'e',
#   'd',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'v',
#   'i',
#   's',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'H',
#   'o',
#   'u',
#   's',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'P',
#   'o',
#   'w',
#   'e',
#   'r',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'C',
#   'l',
#   'e',
#   'a',
#   'n',
#   ' ',
#   'C',
#   'o',
#   'o',
#   'k',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'W',
#   'a',
#   't',
#   'e',
#   'r',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'S',
#   'a',
#   'n',
#   'i',
#   't',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'S',
#   'k',
#   'i',
#   'l',
#   'l',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'H',
#   'e',
#   'a',
#   'l',
#   't',
#   'h',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'I',
#   'n',
#   's',
#   'u',
#   'r',
#   'a',
#   'n',
#   'c',
#   'e',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'a',
#   'n',
#   'd',
#   ' ',
#   'C',
#   'o',
#   'n',
#   'n',
#   'e',
#   'c',
#   't',
#   'i',
#   'v',
#   'i',
#   't',
#   'y',
#   ' ',
#   'f',
#   'o',
#   'r',
#   ' ',
#   'A',
#   'l',
#   'l',
#   '.',
#   '\n',
#   '“',
#   'R',
#   'e',
#   'm',
#   'e',
#   'm',
#   'b',
#   'e',
#   'r',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'f',
#   'i',
#   'r',
#   's',
#   't',
#   ' ',
#   'P',
#   'r',
#   'i',
#   'm',
#   'e',
#   ' ',
#   'M',
#   'i',
#   'n',
#   'i',
#   's',
#   't',
#   'e',
#   'r',
#   ',',
#   ' ',
#   'P',
#   'a',
#   'n',
#   'd',
#   'i',
#   't',
#   ' ',
#   'J',
#   'a',
#   'w',
#   'a',
#   'h',
#   'a',
#   'r',
#   'l',
#   'a',
#   'l',
#   ' ',
#   'N',
#   'e',
#   'h',
#   'r',
#   'u',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   'h',
#   'i',
#   's',
#   ' ',
#   'b',
#   'i',
#   'r',
#   't',
#   'h',
#   ' ',
#   'a',
#   'n',
#   'n',
#   'i',
#   'v',
#   'e',
#   'r',
#   's',
#   'a',
#   'r',
#   'y',
#   '.',
#   '\n',
#   'I',
#   't',
#   ' ',
#   'w',
#   'i',
#   'l',
#   'l',
#   ' ',
#   'h',
#   'e',
#   'l',
#   'p',
#   ' ',
#   's',
#   'p',
#   'r',
#   'e',
#   'a',
#   'd',
#   ' ',
#   'a',
#   'w',
#   'a',
#   'r',
#   'e',
#   'n',
#   'e',
#   's',
#   's',
#   ' ',
#   'a',
#   'b',
#   'o',
#   'u',
#   't',
#   ' ',
#   'G',
#   'a',
#   'n',
#   'd',
#   'h',
#   'i',
#   'a',
#   'n',
#   ' ',
#   'c',
#   'u',
#   'l',
#   't',
#   'u',
#   'r',
#   'e',
#   ',',
#   ' ',
#   'v',
#   'a',
#   'l',
#   'u',
#   'e',
#   's',
#   ' ',
#   'a',
#   'n',
#   'd',
#   ' ',
#   'p',
#   'h',
#   'i',
#   'l',
#   'o',
#   's',
#   'o',
#   'p',
#   'h',
#   'y',
#   '.',
#   '\n',
#   'S',
#   'p',
#   'e',
#   'a',
#   'k',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'o',
#   'c',
#   'c',
#   'a',
#   's',
#   'i',
#   'o',
#   'n',
#   ',',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'P',
#   'r',
#   'i',
#   'm',
#   'e',
#   ' ',
#   'M',
#   'i',
#   'n',
#   'i',
#   's',
#   't',
#   'e',
#   'r',
#   ' ',
#   's',
#   'a',
#   'i',
#   'd',
#   ' ',
#   't',
#   'h',
#   'e',
#   'r',
#   'e',
#   ' ',
#   'i',
#   's',
#   ' ',
#   's',
#   'o',
#   ' ',
#   'm',
#   'u',
#   'c',
#   'h',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'l',
#   'e',
#   'a',
#   'r',
#   'n',
#   ' ',
#   'f',
#   'r',
#   'o',
#   'm',
#   ' ',
#   'M',
#   'a',
#   'h',
#   'a',
#   't',
#   'm',
#   'a',
#   ' ',
#   'G',
#   'a',
#   'n',
#   'd',
#   'h',
#   'i',
#   '.',
#   '\n',
#   '9',
#   '.',
#   ' ',
#   'T',
#   'h',
#   'e',
#   ' ',
#   'P',
#   'r',
#   'i',
#   'm',
#   'e',
#   ' ',
#   'M',
#   'i',
#   'n',
#   'i',
#   's',
#   't',
#   'e',
#   'r',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'I',
#   'n',
#   'd',
#   'i',
#   'a',
#   ' ',
#   'c',
#   'o',
#   'n',
#   'g',
#   'r',
#   'a',
#   't',
#   'u',
#   'l',
#   'a',
#   't',
#   'e',
#   'd',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'p',
#   ...],
#  0,
#  False,
#  {})

# %%
env.state[-5:]
# Out:
# ['e', 'l', 'h', 'i', '.']
